# %% [markdown]
# # pandas
#
# - Mainly made for working with relational or labled data both easily or initutively.
# - It provides various data struture & operations for manupulating numerical data  & time series.
# - This library is built on top of the NumPy library.
# - It is fast and it is high performance & productivity for users.
# - It provided two data struture ,  they are ,
#      - Series
#      - Data Frame

# %%
#import external data sets

# %%
# !pip install Pandas

# %%
#imoprt necessary libraries

import pandas as pd

# %%
df = pd.read_csv('Salaries (2).csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.rename(columns = {'rank':'Rank'})
# Out:
#          Rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %% [markdown]
# # Series
# - Series is one diamainsional labeled array & capable of holding data of any type (int,float,string,python objects etc.)

# %%
#series creation

# %%
lst = [1,2,3,4,5]
type(lst)
# Out:
# list

# %%
s = pd.Series(lst)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
[s ]
# Out:
# [0    1
#  1    2
#  2    3
#  3    4
#  4    5
#  dtype: int64]

# %%
s = pd.Series(data  = [1,10,2500])
s
# Out:
# 0       1
# 1      10
# 2    2500
# dtype: int64

# %%
d = {1:'A',2:'B',3:'C'}
d
# Out:
# {1: 'A', 2: 'B', 3: 'C'}

# %%
type(d)
# Out:
# dict

# %%
s = pd.Series(d)

# %%
s
# Out:
# 1    A
# 2    B
# 3    C
# dtype: object

# %%
s = pd.Series(data = [10,20,30],
              index=['A','B','C'],
              name = 'My_series')

# %%
s
# Out:
# A    10
# B    20
# C    30
# Name: My_series, dtype: int64

# %%
#Accessing element from a series using index lables.

# %%
s[0]
# Out:
# 10

# %%
s['A']
# Out:
# 10

# %%
s[0:3]
# Out:
# A    10
# B    20
# C    30
# Name: My_series, dtype: int64

# %%
s[0]
# Out:
# 10

# %%
s['A']
# Out:
# 10

# %% [markdown]
# # DataFrame
# - A pandas dataframe is 2D data stucture , like a 2D array or a table with rows and columm.
#  Ways to crete DataFrames
#    - By ceating a nested lists & colname lists.
#    - By creating a Dictionary.

# %%
#1st Approch

# %%
lst = [['Python',90,'Pune'],['ML',100,'Mumbai'],['DL',95,'HYD']]
Col = ['Subject','Mark','City']

# %%
df = pd.DataFrame(data = lst , columns=Col)

# %%
df
# Out:
#   Subject  Mark    City
# 0  Python    90    Pune
# 1      ML   100  Mumbai
# 2      DL    95     HYD

# %%
#2nd Apporch

# %%
df = pd.DataFrame({
'Subject' :['Python','ML','DL'],
'Mark' : [90,100,95],
'City':['Pune','Mumbai','HYD']})

# %%
df
# Out:
#   Subject  Mark    City
# 0  Python    90    Pune
# 1      ML   100  Mumbai
# 2      DL    95     HYD

# %%
#Check no of Rows and Column in DataFrame

# %%
df.shape
# Out:
# (3, 3)

# %%
#Daimension of DataFrame

# %%
df.ndim
# Out:
# 2

# %%
#Data type of each column

# %%
df.dtypes
# Out:
# Subject    object
# Mark        int64
# City       object
# dtype: object

# %%
df.Subject
# Out:
# 0    Python
# 1        ML
# 2        DL
# Name: Subject, dtype: object

# %%
df[['Subject']]
# Out:
#   Subject
# 0  Python
# 1      ML
# 2      DL

# %%
df
# Out:
#   Subject  Mark    City
# 0  Python    90    Pune
# 1      ML   100  Mumbai
# 2      DL    95     HYD

# %%
df['City']
# Out:
# 0      Pune
# 1    Mumbai
# 2       HYD
# Name: City, dtype: object

# %%
#Descriptive stats for df

# %%
df.describe()
# Out:
#         Mark
# count    3.0
# mean    95.0
# std      5.0
# min     90.0
# 25%     92.5
# 50%     95.0
# 75%     97.5
# max    100.0

# %%
df.describe(include= 'O')
# Out:
#        Subject  City
# count        3     3
# unique       3     3
# top     Python  Pune
# freq         1     1

# %%
df.describe(include= 'all')
# Out:
#        Subject   Mark  City
# count        3    3.0     3
# unique       3    NaN     3
# top     Python    NaN  Pune
# freq         1    NaN     1
# mean       NaN   95.0   NaN
# std        NaN    5.0   NaN
# min        NaN   90.0   NaN
# 25%        NaN   92.5   NaN
# 50%        NaN   95.0   NaN
# 75%        NaN   97.5   NaN
# max        NaN  100.0   NaN

# %%
#Getting information about dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Subject  3 non-null      object
#  1   Mark     3 non-null      int64
#  2   City     3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
#Checking null values

# %%
df.isnull().sum()
# Out:
# Subject    0
# Mark       0
# City       0
# dtype: int64

# %% [markdown]
# # Imorting External Dataset

# %%
#load the csv file

# %%
df = pd.read_csv('Salaries (2).csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#reading 1st 5 record

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#reading last 5 records

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
#reading all the records

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#describe the data

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.describe(include='all').T
# Out:
#            count unique   top freq           mean           std      min  \
# rank          78      3  Prof   46            NaN           NaN      NaN
# discipline    78      2     B   42            NaN           NaN      NaN
# phd         78.0    NaN   NaN  NaN      19.705128     12.498425      1.0
# service     78.0    NaN   NaN  NaN      15.051282     12.139768      0.0
# sex           78      2  Male   39            NaN           NaN      NaN
# salary      78.0    NaN   NaN  NaN  108023.782051  28293.661022  57800.0
#
#                 25%       50%        75%       max
# rank            NaN       NaN        NaN       NaN
# discipline      NaN       NaN        NaN       NaN
# phd           10.25      18.5      27.75      56.0
# service        5.25      14.5      20.75      51.0
# sex             NaN       NaN        NaN       NaN
# salary      88612.5  104671.0  126774.75  186960.0

# %%
#Extracting only coloumn name

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
# 5     20
# 6     20
# 7     18
# 8     29
# 9     51
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# 16     8
# 17     4
# 18    19
# 19    29
# 20     4
# 21    33
# 22     4
# 23     2
# 24    30
# 25    35
# 26    38
# 27    45
# 28     7
# 29    21
# 30     9
# 31    22
# 32    27
# 33    18
# 34    12
# 35    28
# 36    45
# 37    20
# 38     4
# 39    18
# 40    39
# 41    13
# 42     4
# 43     5
# 44    23
# 45    25
# 46    11
# 47    11
# 48    17
# 49    17
# 50    10
# 51    20
# 52    12
# 53     5
# 54    25
# 55     2
# 56    10
# 57     3
# 58    36
# 59    12
# 60     3
# 61    13
# 62    14
# 63    29
# 64    26
# 65    36
# 66     7
# 67    17
# 68     4
# 69    28
# 70     8
# 71    12
# 72    24
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, dtype: int64

# %%
df[['phd','salary']]
# Out:
#     phd  salary
# 0    56  186960
# 1    12   93000
# 2    23  110515
# 3    40  131205
# 4    20  104800
# 5    20  122400
# 6    20   81285
# 7    18  126300
# 8    29   94350
# 9    51   57800
# 10   39  128250
# 11   23  134778
# 12    1   88000
# 13   35  162200
# 14   25  153750
# 15   17  150480
# 16    8   75044
# 17    4   92000
# 18   19  107300
# 19   29  150500
# 20    4   92000
# 21   33  103106
# 22    4   73000
# 23    2   85000
# 24   30   91100
# 25   35   99418
# 26   38  148750
# 27   45  155865
# 28    7   91300
# 29   21  123683
# 30    9  107008
# 31   22  155750
# 32   27  103275
# 33   18  120000
# 34   12  119800
# 35   28  126933
# 36   45  146856
# 37   20  102000
# 38    4   91000
# 39   18  129000
# 40   39  137000
# 41   13   74830
# 42    4   80225
# 43    5   77000
# 44   23  151768
# 45   25  140096
# 46   11   74692
# 47   11  103613
# 48   17  111512
# 49   17  122960
# 50   10   97032
# 51   20  127512
# 52   12  105000
# 53    5   73500
# ...

# %%
#selecting column with loc and iloc

# %%
#loc function
#in loc function last number is included

# %%
df.head(2)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.loc[10.:15,'phd']
# Out:
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# Name: phd, dtype: int64

# %%
df.loc[10:15,'phd':'salary']
# Out:
#     phd  service   sex  salary
# 10   39       33  Male  128250
# 11   23       23  Male  134778
# 12    1        0  Male   88000
# 13   35       33  Male  162200
# 14   25       19  Male  153750
# 15   17        3  Male  150480

# %%
df.head(2)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[50:56,1]
# Out:
# 50    B
# 51    B
# 52    A
# 53    A
# 54    A
# 55    A
# Name: discipline, dtype: object

# %%
df.iloc[50:56,0:3]
# Out:
#          rank discipline  phd
# 50   AsstProf          B   10
# 51       Prof          B   20
# 52       Prof          A   12
# 53   AsstProf          A    5
# 54  AssocProf          A   25
# 55   AsstProf          A    2

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
#values count

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df['discipline'].value_counts()
# Out:
# discipline
# B    42
# A    36
# Name: count, dtype: int64

# %%
df['sex'].value_counts(
)
# Out:
# sex
# Male      39
# Female    39
# Name: count, dtype: int64

# %%
df.rename(columns= {'rank':'Rank'})
# Out:
#          Rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.rename(columns=
         {'discipline':'Discipline','phd':'PHD'},inplace=True)

# %%
#for permenant change use "inplace" function and kept it true or reassign the element
#i.e. df=df and the operation that you want to change....

# %%
df
# Out:
#          rank Discipline  PHD  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.head(10)
# Out:
#         rank Discipline  PHD  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800
